# %%
import pandas as pd

# %%
df = pd.read_csv("dim_match_summary.csv")
df
# Out:
#            team1         team2        winner      margin       ground  \
# 0          India  South Africa         India      7 runs   Bridgetown
# 1        England         India         India     68 runs   Providence
# 2    Afghanistan  South Africa  South Africa   9 wickets      Tarouba
# 3    Afghanistan    Bangladesh   Afghanistan      8 runs    Kingstown
# 4      Australia         India         India     24 runs   Gros Islet
# 5    West Indies  South Africa  South Africa   3 wickets  North Sound
# 6        England        U.S.A.       England  10 wickets   Bridgetown
# 7    Afghanistan     Australia   Afghanistan     21 runs    Kingstown
# 8     Bangladesh         India         India     50 runs  North Sound
# 9    West Indies        U.S.A.   West Indies   9 wickets   Bridgetown
# 10       England  South Africa  South Africa      7 runs   Gros Islet
# 11     Australia    Bangladesh     Australia     28 runs  North Sound
# ...

# %%
df.shape
# Out:
# (52, 7)

# %%
df.head(11)
# Out:
#           team1         team2        winner      margin       ground  \
# 0         India  South Africa         India      7 runs   Bridgetown
# 1       England         India         India     68 runs   Providence
# 2   Afghanistan  South Africa  South Africa   9 wickets      Tarouba
# 3   Afghanistan    Bangladesh   Afghanistan      8 runs    Kingstown
# 4     Australia         India         India     24 runs   Gros Islet
# 5   West Indies  South Africa  South Africa   3 wickets  North Sound
# 6       England        U.S.A.       England  10 wickets   Bridgetown
# 7   Afghanistan     Australia   Afghanistan     21 runs    Kingstown
# 8    Bangladesh         India         India     50 runs  North Sound
# 9   West Indies        U.S.A.   West Indies   9 wickets   Bridgetown
# 10      England  South Africa  South Africa      7 runs   Gros Islet
#
#        matchDate     match_id
# 0   Jun 29, 2024  T20I # 2729
# 1   Jun 27, 2024  T20I # 2724
# 2   Jun 26, 2024  T20I # 2723
# ...

# %%
match_ids_dict={}

for index,row in df.iterrows():
    key1 = row["team1"]+"vs"+row["team2"]
    key2 = row["team2"]+"vs"+row["team1"]

    match_ids_dict[key1] = row["match_id"]
    match_ids_dict[key2] = row["match_id"]

match_ids_dict
# Out:
# {'IndiavsSouth Africa': 'T20I # 2729',
#  'South AfricavsIndia': 'T20I # 2729',
#  'EnglandvsIndia': 'T20I # 2724',
#  'IndiavsEngland': 'T20I # 2724',
#  'AfghanistanvsSouth Africa': 'T20I # 2723',
#  'South AfricavsAfghanistan': 'T20I # 2723',
#  'AfghanistanvsBangladesh': 'T20I # 2722',
#  'BangladeshvsAfghanistan': 'T20I # 2722',
#  'AustraliavsIndia': 'T20I # 2721',
#  'IndiavsAustralia': 'T20I # 2721',
#  'West IndiesvsSouth Africa': 'T20I # 2720',
#  'South AfricavsWest Indies': 'T20I # 2720',
#  'EnglandvsU.S.A.': 'T20I # 2719',
#  'U.S.A.vsEngland': 'T20I # 2719',
#  'AfghanistanvsAustralia': 'T20I # 2717',
#  'AustraliavsAfghanistan': 'T20I # 2717',
#  'BangladeshvsIndia': 'T20I # 2716',
#  'IndiavsBangladesh': 'T20I # 2716',
#  'West IndiesvsU.S.A.': 'T20I # 2713',
#  'U.S.A.vsWest Indies': 'T20I # 2713',
#  'EnglandvsSouth Africa': 'T20I # 2712',
#  'South AfricavsEngland': 'T20I # 2712',
#  'AustraliavsBangladesh': 'T20I # 2711',
# ...

# %% [markdown]
# batting summary

# %%
df_bat = pd.read_csv("fact_bating_summary.csv")
df_bat
# Out:
#                           match  teamInnings  battingPos       batsmanName  \
# 0             Pakistan Vs U.S.A     Pakistan           1   Mohammad Rizwan
# 1             Pakistan Vs U.S.A     Pakistan           2     Babar Azam(c)
# 2             Pakistan Vs U.S.A     Pakistan           3        Usman Khan
# 3             Pakistan Vs U.S.A     Pakistan           4      Fakhar Zaman
# 4             Pakistan Vs U.S.A     Pakistan           5       Shadab Khan
# ..                          ...          ...         ...               ...
# 847  West Indies Vs New Zealand  New Zealand           7     James Neesham
# 848  West Indies Vs New Zealand  New Zealand           8  Mitchell Santner
# 849  West Indies Vs New Zealand  New Zealand           9       Tim Southee
# 850  West Indies Vs New Zealand  New Zealand          10       Trent Boult
# 851  West Indies Vs New Zealand  New Zealand          11   Lockie Ferguson
#
#      runs  balls  4s  6s      SR out/not_out     match_id
# ...

# %%
df_bat.head(11)
# Out:
#                 match teamInnings  battingPos          batsmanName  runs  \
# 0   Pakistan Vs U.S.A    Pakistan           1      Mohammad Rizwan     9
# 1   Pakistan Vs U.S.A    Pakistan           2        Babar Azam(c)    44
# 2   Pakistan Vs U.S.A    Pakistan           3           Usman Khan     3
# 3   Pakistan Vs U.S.A    Pakistan           4         Fakhar Zaman    11
# 4   Pakistan Vs U.S.A    Pakistan           5          Shadab Khan    40
# 5   Pakistan Vs U.S.A    Pakistan           6            Azam Khan     0
# 6   Pakistan Vs U.S.A    Pakistan           7       Iftikhar Ahmed    18
# 7   Pakistan Vs U.S.A    Pakistan           8  Shaheen Shah Afridi    23
# 8   Pakistan Vs U.S.A    Pakistan           9           Haris Rauf     3
# 9   Pakistan Vs U.S.A       U.S.A           1        Steven Taylor    12
# 10  Pakistan Vs U.S.A       U.S.A           2      Monank Patel(c)    50
#
#     balls  4s  6s      SR out/not_out     match_id
# ...

# %% [markdown]
# BOWING summary

# %%
df_bowl = pd.read_csv("fact_bowling_summary.csv")
df_bowl
# Out:
#                      match   bowlingTeam            bowlerName  overs  maiden  \
# 0    India Vs South Africa  South Africa          Marco Jansen    4.0       0
# 1    India Vs South Africa  South Africa        Keshav Maharaj    3.0       0
# 2    India Vs South Africa  South Africa         Kagiso Rabada    4.0       0
# 3    India Vs South Africa  South Africa         Aiden Markram    2.0       0
# 4    India Vs South Africa  South Africa         Anrich Nortje    4.0       0
# ..                     ...           ...                   ...    ...     ...
# 590   Netherlands Vs Nepal         Nepal           Sompal Kami    4.0       0
# 591   Netherlands Vs Nepal         Nepal            Gulsan Jha    2.0       0
# 592   Netherlands Vs Nepal         Nepal  Dipendra Singh Airee    2.0       0
# 593   Netherlands Vs Nepal         Nepal        Abinash Bohara    3.4       0
# 594   Netherlands Vs Nepal         Nepal          Sagar Dhakal    4.0       0
#
# ...

# %%
df_bowl.head()
# Out:
#                    match   bowlingTeam      bowlerName  overs  maiden  runs  \
# 0  India Vs South Africa  South Africa    Marco Jansen    4.0       0    49
# 1  India Vs South Africa  South Africa  Keshav Maharaj    3.0       0    23
# 2  India Vs South Africa  South Africa   Kagiso Rabada    4.0       0    36
# 3  India Vs South Africa  South Africa   Aiden Markram    2.0       0    16
# 4  India Vs South Africa  South Africa   Anrich Nortje    4.0       0    26
#
#    wickets  economy  0s  4s  6s  wides  noBalls     match_id
# 0        1    12.25   4   5   2      1        1  T20I # 2729
# 1        2     7.66  10   3   1      0        0  T20I # 2729
# 2        1     9.00   8   2   2      2        0  T20I # 2729
# 3        0     8.00   1   0   1      0        0  T20I # 2729
# 4        2     6.50   7   2   0      2        0  T20I # 2729

# %%
df_player = pd.read_csv("dim_players.csv")
df_player
# Out:
#                  name              team  \
# 0        Andries Gous             U.S.A
# 1     Rohit Sharma(c)             India
# 2       Kuldeep Yadav             India
# 3          Matt Henry       New Zealand
# 4      Robinson Obuya            Uganda
# ..                ...               ...
# 272  Scott Edwards(c)       Netherlands
# 273       Josh Little           Ireland
# 274      Roger Mukasa            Uganda
# 275        Assad Vala  Papua New Guinea
# 276     Michael Leask          Scotland
#
#                                                  image    battingStyle  \
# 0                                                  NaN  Right hand Bat
# 1    https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# 2    https://img1.hscicdn.com/image/upload/f_auto,t...   Left hand Bat
# 3                                                  NaN  Right hand Bat
# 4                                                  NaN  Right hand Bat
# ...

# %%
df_player.head()
# Out:
#               name         team  \
# 0     Andries Gous        U.S.A
# 1  Rohit Sharma(c)        India
# 2    Kuldeep Yadav        India
# 3       Matt Henry  New Zealand
# 4   Robinson Obuya       Uganda
#
#                                                image    battingStyle  \
# 0                                                NaN  Right hand Bat
# 1  https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# 2  https://img1.hscicdn.com/image/upload/f_auto,t...   Left hand Bat
# 3                                                NaN  Right hand Bat
# 4                                                NaN  Right hand Bat
#
#         playingRole           bowlingStyle  \
# 0      Wicketkeeper                    NaN
# 1  Top order Batter     Right arm Offbreak
# 2            Bowler    Left arm Wrist spin
# 3            Bowler  Right arm Fast medium
# 4            Batter                    NaN
#
#                                          description
# ...

# %% [markdown]
# NO IMAGE PLAYER

# %%
df_no_image_player = df_player.copy()

# %%
df_no_image_player.head()
# Out:
#               name         team  \
# 0     Andries Gous        U.S.A
# 1  Rohit Sharma(c)        India
# 2    Kuldeep Yadav        India
# 3       Matt Henry  New Zealand
# 4   Robinson Obuya       Uganda
#
#                                                image    battingStyle  \
# 0                                                NaN  Right hand Bat
# 1  https://img1.hscicdn.com/image/upload/f_auto,t...  Right hand Bat
# 2  https://img1.hscicdn.com/image/upload/f_auto,t...   Left hand Bat
# 3                                                NaN  Right hand Bat
# 4                                                NaN  Right hand Bat
#
#         playingRole           bowlingStyle  \
# 0      Wicketkeeper                    NaN
# 1  Top order Batter     Right arm Offbreak
# 2            Bowler    Left arm Wrist spin
# 3            Bowler  Right arm Fast medium
# 4            Batter                    NaN
#
#                                          description
# ...

# %%
df_no_image_player.drop(columns=["image"], inplace=True)
df_no_image_player.head()
# Out:
#               name         team    battingStyle       playingRole  \
# 0     Andries Gous        U.S.A  Right hand Bat      Wicketkeeper
# 1  Rohit Sharma(c)        India  Right hand Bat  Top order Batter
# 2    Kuldeep Yadav        India   Left hand Bat            Bowler
# 3       Matt Henry  New Zealand  Right hand Bat            Bowler
# 4   Robinson Obuya       Uganda  Right hand Bat            Batter
#
#             bowlingStyle                                        description
# 0                    NaN                                                NaN
# 1     Right arm Offbreak                                                NaN
# 2    Left arm Wrist spin                                                NaN
# 3  Right arm Fast medium  A slippery fast bowler, Matt Henry almost didn...
# 4                    NaN                                                NaN

# %%
df_no_image_player.to_csv("df_no_image_player",index = True)
